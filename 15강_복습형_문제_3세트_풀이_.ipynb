# %% [markdown]
# <a href="https://colab.research.google.com/github/hr7git/Data-Analysis-with-Open-Source/blob/main/15%EA%B0%95_%EB%B3%B5%EC%8A%B5%ED%98%95_%EB%AC%B8%EC%A0%9C_3%EC%84%B8%ED%8A%B8_%ED%92%80%EC%9D%B4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * **정답 및 해설:**
#
# ```python
# df['MA5'] = df['Close'].rolling(window=5).mean()
# # 해설: 최근 5일간의 주가 평균을 구하면, 매일의 급격한 변화(노이즈)가 줄어들어 추세를 보기 편해집니다.
#
# ```
#
# ---

# %% [markdown]
# ---
# * **정답 및 해설:**
#
# ```python
# df['Signal'] = np.where(df['MA5'] > df['MA20'], 1, 0)
# # 해설: 수학적으로 두 함수의 교차점을 찾는 과정입니다. 단기 추세가 장기 추세를 앞지를 때를 '매수 타이밍'으로 정의한 것입니다.
#
# ```
#
# ---

# %% [markdown]
# ---
# * **정답 및 해설:**
#
# ```python
# X = df_clean[['MA5', 'MA20']]
# y = df_clean['Target']
# # 해설: 머신러닝의 핵심은 '특징(X)'과 '정답(y)' 사이의 관계 함수를 컴퓨터가 스스로 찾게 하는 것입니다.
#
# ```
#
# ---
